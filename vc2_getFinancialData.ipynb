# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
# %matplotlib inline
import quandl # pip install quandl
quandl.ApiConfig.api_key = "zn5-6teANUU-aeaQrYoV"

# %%
mydata = quandl.get("EIA/PET_RWTC_D") # returns pandas
# mydata = quandl.get("EIA/PET_RWTC_D", returns="numpy")  # tuple
mydata.head()
# Out:
#             Value
# Date
# 1986-01-02  25.56
# 1986-01-03  26.00
# 1986-01-06  26.53
# 1986-01-07  25.85
# 1986-01-08  25.87

# %%
mydata.plot(figsize=(12,6))

# %%
# why does this only go until 2018 - probably when nasdaq bought them
mydata = quandl.get('WIKI/AAPL',start_date='2010-01-01',end_date='2020-03-31')
mydata
# Out:
#               Open    High     Low    Close      Volume  Ex-Dividend  \
# Date
# 2010-01-04  213.43  214.50  212.38  214.010  17633200.0          0.0
# 2010-01-05  214.60  215.59  213.25  214.380  21496600.0          0.0
# 2010-01-06  214.38  215.23  210.75  210.970  19720000.0          0.0
# 2010-01-07  211.75  212.00  209.05  210.580  17040400.0          0.0
# 2010-01-08  210.30  212.00  209.06  211.980  15986100.0          0.0
# ...            ...     ...     ...      ...         ...          ...
# 2018-03-21  175.04  175.09  171.26  171.270  35247358.0          0.0
# 2018-03-22  170.00  172.68  168.60  168.845  41051076.0          0.0
# 2018-03-23  168.39  169.92  164.94  164.940  40248954.0          0.0
# 2018-03-26  168.07  173.10  166.44  172.770  36272617.0          0.0
# 2018-03-27  173.68  175.15  166.92  168.340  38962839.0          0.0
#
#             Split Ratio   Adj. Open   Adj. High    Adj. Low  Adj. Close  \
# Date
# ...

# %%
# short interest data, 2 day lag
mydata = quandl.get('BATS/BATS_NFLX',start_date='2020-01-31',end_date='2020-03-31')
mydata
# Out:
#             Short Volume  Total Volume
# Date
# 2020-01-31      307727.0      498686.0
# 2020-02-03      496391.0      627691.0
# 2020-02-04      451638.0      583838.0
# 2020-02-05      354232.0      442507.0
# 2020-02-06      203591.0      282139.0
# 2020-02-07      344444.0      421664.0
# 2020-02-10      215142.0      323359.0
# 2020-02-11      294662.0      370012.0
# 2020-02-12      281842.0      373218.0
# 2020-02-13      281596.0      414183.0
# 2020-02-14      216013.0      323908.0
# 2020-02-18      308268.0      439197.0
# 2020-02-19      259773.0      391730.0
# 2020-02-20      234682.0      372284.0
# 2020-02-21      240520.0      323336.0
# 2020-02-24      346253.0      501702.0
# 2020-02-25      390474.0      577938.0
# 2020-02-26      451124.0      673129.0
# 2020-02-27      470389.0      797369.0
# 2020-02-28      489617.0      777075.0
# 2020-03-02      354582.0      507899.0
# 2020-03-03      461108.0      688215.0
# 2020-03-04      267183.0      432540.0
# ...

# %%
# HKEX data pretty good
mydata = quandl.get('HKEX/00019',start_date='2020-01-31',end_date='2020-03-31')
mydata
# Out:
#             Nominal Price Net Change Change (%)    Bid    Ask P/E(x)   High  \
# Date
# 2020-01-31          68.85       None       None  68.85  69.00   None  70.90
# 2020-02-03          67.90       None       None  67.90  68.00   None  68.80
# 2020-02-04          68.50       None       None  68.50  68.55   None  69.85
# 2020-02-05          69.05       None       None  69.05  69.10   None  70.00
# 2020-02-06          71.35       None       None  71.25  71.35   None  72.20
# 2020-02-07          71.95       None       None  71.80  71.95   None  72.40
# 2020-02-10          71.20       None       None  71.15  71.20   None  71.90
# 2020-02-11          72.55       None       None  72.50  72.55   None  73.45
# 2020-02-12          73.00       None       None  72.80  73.00   None  73.35
# 2020-02-13          73.40       None       None  73.15  73.40   None  73.40
# 2020-02-14          74.40       None       None  74.30  74.40   None  74.40
# ...

# %%
# US Treasury Yield Data - very good
mydata = quandl.get('USTREASURY/YIELD',start_date='2020-01-31',end_date='2020-03-31')
mydata.tail()
# FED/RIFLDIY05_N_A # does not work
# USTREASURY/YIELD
# Out:
#             1 MO  2 MO  3 MO  6 MO  1 YR  2 YR  3 YR  5 YR  7 YR  10 YR  \
# Date
# 2020-03-23  0.01  0.04  0.02  0.08  0.17  0.28  0.31  0.38  0.63   0.76
# 2020-03-24  0.01  0.01  0.01  0.09  0.25  0.38  0.44  0.52  0.75   0.84
# 2020-03-25  0.00  0.00  0.00  0.07  0.19  0.34  0.41  0.56  0.77   0.88
# 2020-03-26  0.01  0.01  0.00  0.04  0.13  0.30  0.36  0.51  0.72   0.83
# 2020-03-27  0.01  0.03  0.03  0.02  0.11  0.25  0.30  0.41  0.60   0.72
#
#             20 YR  30 YR
# Date
# 2020-03-23   1.12   1.33
# 2020-03-24   1.19   1.39
# 2020-03-25   1.23   1.45
# 2020-03-26   1.20   1.42
# 2020-03-27   1.09   1.29

# %%
from datetime import datetime
# df.loc[[2,4,10,99],['Name','HP']]
# might need a for loop for this:
mydata.loc['2020-01-31'].plot()
mydata.loc['2020-03-20'].plot()
mydata.loc['2020-03-27'].plot()

# %%
# series slice
mydata.loc['2020-03-20':'2020-03-27'].plot()
# specific selection - need datetime conversion 
#df.loc[['viper', 'sidewinder']]
# fix is in next cell

# the transpose fixes the plot (plot columns on x axis and use index as y axis using pandas)
mydata.loc[[datetime(2020,3,20),datetime(2020,3,27)]].T.plot()
mydata.loc[[datetime.strptime('2020-03-20', '%Y-%m-%d'),datetime.strptime('2020-03-27', '%Y-%m-%d')]].T.plot()

# %%
mydata = quandl.get('ML/AAOAS',start_date='2020-01-31',end_date='2020-03-31')
# MORTGAGE DATA
# WFC/RR_JUMBO_30YFIXED_IR
# WFC/RR_JUMBO_15YFIXED_APR
# WFC/RR_JUMBO_71ARM_APR
# WFC/RR_JUMBO_71ARM_IR
# WFC/RR_CON_30YFIXED_APR

# CORPORATE BOND DATA
# ML/AAAEY
# ML/AAY
# ML/AAOAS
# ML/AEY
# ML/BBBEY
# ML/BEY
# ML/CCCEY
mydata
# Out:
#             BAMLC0A2CAA
# DATE
# 2020-01-31         0.60
# 2020-02-03         0.60
# 2020-02-04         0.59
# 2020-02-05         0.58
# 2020-02-06         0.57
# 2020-02-07         0.57
# 2020-02-10         0.57
# 2020-02-11         0.58
# 2020-02-12         0.56
# 2020-02-13         0.56
# 2020-02-14         0.56
# 2020-02-17         0.56
# 2020-02-18         0.56
# 2020-02-19         0.56
# 2020-02-20         0.57
# 2020-02-21         0.59
# 2020-02-24         0.62
# 2020-02-25         0.64
# 2020-02-26         0.65
# 2020-02-27         0.69
# 2020-02-28         0.77
# 2020-02-29         0.77
# 2020-03-02         0.79
# 2020-03-03         0.78
# 2020-03-04         0.78
# 2020-03-05         0.80
# 2020-03-06         0.91
# 2020-03-09         1.21
# 2020-03-10         1.16
# 2020-03-11         1.21
# 2020-03-12         1.42
# 2020-03-13         1.49
# 2020-03-16         1.68
# 2020-03-17         1.79
# 2020-03-18         2.04
# 2020-03-19         2.40
# 2020-03-20         2.76
# ...

# %%
# datetime library

# To illustrate the order of arguments
my_year = 2020
my_month = 1
my_day = 2
my_hour = 13
my_minute = 30
my_second = 20

# basic example
my_date = datetime(my_year,my_month,my_day)
type(my_date)
my_date.day
my_date.month

# January 2nd, 2020 at 13:30:20
my_date_time = datetime(my_year,my_month,my_day,my_hour,my_minute,my_second)
my_date_time.second

# Date Array
first_two = [datetime(2019,1,1),datetime(2020,1,3)]
type(first_two)
dt_index = pd.DatetimeIndex(first_two)
r_data = np.random.randn(2,2)
cols = ['a','b']
df = pd.DataFrame(r_data, dt_index, cols)
df

# latest date index
df.index.argmax()
# latest date timestamp
df.index.max()
# others
df.index.argmin()
df.index.min()
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
df = pd.read_csv('walmart_stock.csv', index_col='Date',parse_dates=True)
df['Open'].plot(figsize=(12,6))
df.rolling(7).mean().head(20) # first 6 rows are NaN
# quick plot
df.rolling(window=7).mean()['Close']
df.rolling(window=30).mean()['Close'].plot()

# %%
# plotting with legend
df['Close 7D MA'] = df['Close'].rolling(window=7).mean()
df['Close 30D MA'] = df['Close'].rolling(window=30).mean()
df[['Close', 'Close 30D MA','Close 7D MA']].plot(figsize=(16,6)) 

# Close 20 MA
df['Close 20D Mean'] = df['Close'].rolling(20).mean()

# Upper = 20MA + 2*std(20)
df['Upper 20D'] = df['Close 20D Mean'] + 2*(df['Close'].rolling(20).std())

# Lower = 20MA - 2*std(20)
df['Lower 20D'] = df['Close 20D Mean'] - 2*(df['Close'].rolling(20).std())
df[['Close', 'Upper 20D','Lower 20D']].plot(figsize=(16,6)) 
df[['Close', 'Upper 20D','Lower 20D']].tail(200).plot(figsize=(16,6))
